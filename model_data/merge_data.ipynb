# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import itertools

# from sklearn.preprocessing import StandardScaler    # 표준화.
# from sklearn.cluster import KMeans                  # 군집화

import warnings  
warnings.filterwarnings('ignore')

# %%
path = 'E:\기업프로젝트\profile_ymti_data_ver2'
path2 = 'E:\기업프로젝트\log_data_1027_2'
df = pd.read_csv(path+'\ymti_data.csv',engine='c',encoding='UTF-8')                                     # 원데이터
df_2030 = pd.read_csv(path + '\ymti_edit_data.csv',engine='c',encoding='UTF-8')                         # 20,30대 YMTI 데이터

want_df = pd.read_csv(path2 + '\want_log.csv',engine='c',encoding='UTF-8')                              # 만나고 싶어요 로그
concn_df = pd.read_csv(path2 + '\concn_log.csv',engine='c',encoding='UTF-8')                            # 관심있어요 로그
msg_df = pd.read_csv(path2 + '\msg_log.csv',engine='c',encoding='UTF-8')                                # 메세지 로그
pf_view_df = pd.read_csv(path2 + '\pf_view_log.csv',engine='c',encoding='UTF-8')                        # 프로필 열람 로그

married_df = pd.read_csv(path2 + '\married_success_sample.csv',engine='c',encoding='UTF-8')             # 결혼 성공 사례 로그

# %%
df_2030
# Out:
#        mem_no mem_sex  mem_age mem_loc  mem_birth_ddi  mate_blood pf_ins_yn  \
# 0     1613793       m       38       d              4           3         y
# 1     1186343       m       38       h              4           3         y
# 2     1525788       m       25       k              5           3         y
# 3     1613346       m       37       b              5           2         y
# 4     1365388       f       36       i              6           2         y
# ...       ...     ...      ...     ...            ...         ...       ...
# 9335  1680076       f       26       b              4           1         y
# 9336  1629193       f       27       a              3           3         y
# 9337  1386307       f       32       b             10           3         y
# 9338  1680916       m       37       i              5           1         y
# 9339  1360816       f       27       e              3           1         y
#
#      mbti_code   food_cat
# 0         INFJ        C,K
# ...

# %% [markdown]
# * 만나고 싶어요

# %%
want_df
# Out:
#        mem_no mem_sex acpt_yn mem_mbti_code  ptr_mem_no ptr_mem_sex  \
# 0     1663087       m       y          ISFP     1666973           f
# 1     1429227       m       y          INFP     1646015           f
# 2     1414642       m       y          INFP     1619629           f
# 3     1525643       m       y          ENTP     1619629           f
# 4      967298       m       y          ESTJ     1661325           f
# ...       ...     ...     ...           ...         ...         ...
# 1242  1670270       m       y          ESFJ     1345654           f
# 1243  1560654       m       y          INFP     1602829           f
# 1244   799363       f       y          INFJ     1545903           m
# 1245  1288260       m       y          ESFJ     1592728           f
# 1246  1661751       m       y          ENTJ     1667547           f
#
#      ptr_acpt_yn ptr_mbti_code open_slct want_slct read_yn  \
# 0              n          ISFP         f         c       y
# ...

# %%
want_df.mem_mbti_code.unique()
# Out:
# array(['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
#        'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'],
#       dtype=object)

# %%
# I
want_df1 = dict(want_df[want_df['mem_mbti_code']=="ISTJ"].ptr_mbti_code.value_counts())
want_df2 = dict(want_df[want_df['mem_mbti_code']=="ISTP"].ptr_mbti_code.value_counts())
want_df3 = dict(want_df[want_df['mem_mbti_code']=="ISFJ"].ptr_mbti_code.value_counts())
want_df4 = dict(want_df[want_df['mem_mbti_code']=="ISFP"].ptr_mbti_code.value_counts())
want_df5 = dict(want_df[want_df['mem_mbti_code']=="INFJ"].ptr_mbti_code.value_counts())
want_df6 = dict(want_df[want_df['mem_mbti_code']=="INFP"].ptr_mbti_code.value_counts())
want_df7 = dict(want_df[want_df['mem_mbti_code']=="INTJ"].ptr_mbti_code.value_counts())
want_df8 = dict(want_df[want_df['mem_mbti_code']=="INTP"].ptr_mbti_code.value_counts())
# E
want_df9 = dict(want_df[want_df['mem_mbti_code']=="ESTJ"].ptr_mbti_code.value_counts())
want_df10 = dict(want_df[want_df['mem_mbti_code']=="ESTP"].ptr_mbti_code.value_counts())
want_df11 = dict(want_df[want_df['mem_mbti_code']=="ESFJ"].ptr_mbti_code.value_counts())
want_df12 = dict(want_df[want_df['mem_mbti_code']=="ESFP"].ptr_mbti_code.value_counts())
want_df13 = dict(want_df[want_df['mem_mbti_code']=="ENFJ"].ptr_mbti_code.value_counts())
want_df14 = dict(want_df[want_df['mem_mbti_code']=="ENFP"].ptr_mbti_code.value_counts())
want_df15 = dict(want_df[want_df['mem_mbti_code']=="ENTJ"].ptr_mbti_code.value_counts())
want_df16 = dict(want_df[want_df['mem_mbti_code']=="ENTP"].ptr_mbti_code.value_counts())


want_df1
# Out:
# {'ISFP': 8,
#  'INFP': 4,
#  'ENFP': 3,
#  'INFJ': 3,
#  'ENFJ': 2,
#  'ESFJ': 2,
#  'INTP': 2,
#  'ENTJ': 1,
#  'ESTJ': 1,
#  'ISFJ': 1,
#  'ENTP': 1,
#  'ESFP': 1,
#  'ESTP': 1,
#  'ISTP': 1}

# %%
want_df1 = pd.DataFrame(want_df1,index =['ISTJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
want_df2 = pd.DataFrame(want_df2,index =['ISTP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
want_df3 = pd.DataFrame(want_df3,index =['ISFJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
want_df4 = pd.DataFrame(want_df4,index =['ISFP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
want_df5 = pd.DataFrame(want_df5,index =['INFJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
want_df6 = pd.DataFrame(want_df6,index =['INFP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
want_df7 = pd.DataFrame(want_df7,index =['INTJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
want_df8 = pd.DataFrame(want_df8,index =['INTP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])


want_df9 = pd.DataFrame(want_df9,index =['ESTJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
want_df10 = pd.DataFrame(want_df10,index =['ESTP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
want_df11 = pd.DataFrame(want_df11,index =['ESFJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
want_df12 = pd.DataFrame(want_df12,index =['ESFP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
want_df13 = pd.DataFrame(want_df13,index =['ENFJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
want_df14 = pd.DataFrame(want_df14,index =['ENFP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
want_df15 = pd.DataFrame(want_df15,index =['ENTJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
want_df16 = pd.DataFrame(want_df16,index =['ENTP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])

# %%
new_want = pd.concat([want_df1,want_df2,want_df3,want_df4,want_df5,want_df6,want_df7,want_df8,want_df9,want_df10,want_df11,want_df12,want_df13,want_df14,want_df15,want_df16])
new_want = new_want.fillna(0)
new_want = new_want.transpose()
new_want
# Out:
#       ISTJ  ISTP  ISFJ  ISFP  INFJ  INFP  INTJ  INTP  ESTJ  ESTP  ESFJ  ESFP  \
# ISFP     8     4     7    35    13    35     9     5    14     4    10    12
# INFP     4    13    12    24    15    60    11     8    23     4     4    11
# ENTP     1     0     1     2     5     9     1     0     1     1     1     4
# ESTJ     1     1     1     2     4    15     1     0     3     1     2     1
# ESFP     1     5     3    11     5    19     3     4     5     1     1     5
# ESFJ     2     1     3    12     4     6     2     3     8     1     1     7
# ENTJ     1     1     2     2     2     9     2     4     5     0     0     2
# INFJ     3     1     1     9     3    23     1     6    10     0     5     6
# ENFP     3     2     4    10    13    21     1     3     8     2     3     5
# ISFJ     1     6     8    15     8    18     3     6    14     1     4    10
# INTJ     0     1     2     8     3     5     0     1     2     1     1     1
# ...

# %%
new_want[['ISTJ']].max()
# Out:
# ISTJ    8
# dtype: int64

# %% [markdown]
# * 관심있어요

# %%
concn_df
# Out:
#         mem_no mem_sex mem_mbti_code  ptr_mem_no ptr_mem_sex ptr_mbti_code  \
# 0      1035596       m          INFJ     1490420           f          ISFJ
# 1      1035596       m          INFJ     1650613           f          ISFP
# 2      1035596       m          INFJ     1654611           f          ISTP
# 3      1575626       m          ENFP     1490420           f          ISFJ
# 4      1575626       m          ENFP     1668615           f          ENFP
# ...        ...     ...           ...         ...         ...           ...
# 14165   904319       f          ENFP     1202729           m          INFJ
# 14166  1638077       m          INFP     1687681           f          ISFP
# 14167   909076       f          ENFP     1292413           m          INFJ
# 14168  1663346       m          INFP     1684240           f          ENFP
# 14169  1572093       m          INFP      960047           f          ISFP
#
#       open_slct             ins_date
# ...

# %%
# I
concn_df1 = dict(concn_df[concn_df['mem_mbti_code']=="ISTJ"].ptr_mbti_code.value_counts())
concn_df2 = dict(concn_df[concn_df['mem_mbti_code']=="ISTP"].ptr_mbti_code.value_counts())
concn_df3 = dict(concn_df[concn_df['mem_mbti_code']=="ISFJ"].ptr_mbti_code.value_counts())
concn_df4 = dict(concn_df[concn_df['mem_mbti_code']=="ISFP"].ptr_mbti_code.value_counts())
concn_df5 = dict(concn_df[concn_df['mem_mbti_code']=="INFJ"].ptr_mbti_code.value_counts())
concn_df6 = dict(concn_df[concn_df['mem_mbti_code']=="INFP"].ptr_mbti_code.value_counts())
concn_df7 = dict(concn_df[concn_df['mem_mbti_code']=="INTJ"].ptr_mbti_code.value_counts())
concn_df8 = dict(concn_df[concn_df['mem_mbti_code']=="INTP"].ptr_mbti_code.value_counts())
# E
concn_df9 = dict(concn_df[concn_df['mem_mbti_code']=="ESTJ"].ptr_mbti_code.value_counts())
concn_df10 = dict(concn_df[concn_df['mem_mbti_code']=="ESTP"].ptr_mbti_code.value_counts())
concn_df11 = dict(concn_df[concn_df['mem_mbti_code']=="ESFJ"].ptr_mbti_code.value_counts())
concn_df12 = dict(concn_df[concn_df['mem_mbti_code']=="ESFP"].ptr_mbti_code.value_counts())
concn_df13 = dict(concn_df[concn_df['mem_mbti_code']=="ENFJ"].ptr_mbti_code.value_counts())
concn_df14 = dict(concn_df[concn_df['mem_mbti_code']=="ENFP"].ptr_mbti_code.value_counts())
concn_df15 = dict(concn_df[concn_df['mem_mbti_code']=="ENTJ"].ptr_mbti_code.value_counts())
concn_df16 = dict(concn_df[concn_df['mem_mbti_code']=="ENTP"].ptr_mbti_code.value_counts())

# fig = plt.figure(figsize=(30, 20))

# plt.subplot(4, 4, 1)
# concn_cnt = concn_cnt.sort_values(ascending=False)
# concn_cnt.plot.bar(color='green', alpha=0.5)

# plt.subplot(4, 4, 2)
# concn_cnt2 = concn_cnt2.sort_values(ascending=False)
# concn_cnt2.plot.bar(color='green', alpha=0.5)

# %%
concn_df1
# Out:
# {'INFP': 32,
#  'ISFP': 30,
#  'ESFP': 25,
#  'ISFJ': 25,
#  'INFJ': 24,
#  'ENFJ': 20,
#  'ESFJ': 17,
#  'ENFP': 14,
#  'INTP': 13,
#  'ESTP': 12,
#  'INTJ': 10,
#  'ISTP': 10,
#  'ISTJ': 8,
#  'ENTP': 8,
#  'ESTJ': 8,
#  'ENTJ': 7}

# %%
concn_df1 = pd.DataFrame(concn_df1,index =['ISTJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
concn_df2 = pd.DataFrame(concn_df2,index =['ISTP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
concn_df3 = pd.DataFrame(concn_df3,index =['ISFJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
concn_df4 = pd.DataFrame(concn_df4,index =['ISFP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
concn_df5 = pd.DataFrame(concn_df5,index =['INFJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
concn_df6 = pd.DataFrame(concn_df6,index =['INFP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
concn_df7 = pd.DataFrame(concn_df7,index =['INTJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
concn_df8 = pd.DataFrame(concn_df8,index =['INTP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])


concn_df9 = pd.DataFrame(concn_df9,index =['ESTJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
concn_df10 = pd.DataFrame(concn_df10,index =['ESTP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
concn_df11 = pd.DataFrame(concn_df11,index =['ESFJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
concn_df12 = pd.DataFrame(concn_df12,index =['ESFP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
concn_df13 = pd.DataFrame(concn_df13,index =['ENFJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
concn_df14 = pd.DataFrame(concn_df14,index =['ENFP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
concn_df15 = pd.DataFrame(concn_df15,index =['ENTJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
concn_df16 = pd.DataFrame(concn_df16,index =['ENTP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])

# %%
new_concn = pd.concat([concn_df1,concn_df2,concn_df3,concn_df4,concn_df5,concn_df6,concn_df7,concn_df8,concn_df9,concn_df10,concn_df11,concn_df12,concn_df13,concn_df14,concn_df15,concn_df16])
new_concn = new_concn.fillna(0)
new_concn = new_concn.transpose()
new_concn
# Out:
#       ISTJ  ISTP  ISFJ  ISFP  INFJ  INFP  INTJ  INTP  ESTJ  ESTP  ESFJ  ESFP  \
# ISFP    30    85   158   327   197   415    62    95    33    30    72    79
# INFP    32   102   166   367   237   581    96   145    57    24    70    70
# ENTP     8    13    19    44    29    81    13    14     2     3    13    10
# ESTJ     8    15    19    36    34    59     9     7     3     6    18    18
# ESFP    25    50    75   126   101   208    28    66    13    19    54    35
# ESFJ    17    32    44   109    89   145    20    38    12    20    36    33
# ENTJ     7     9    28    52    43    88    11    20     5     2    15    14
# INFJ    24    46    54   166   108   205    26    45    17    16    44    44
# ENFP    14    48    78   168   134   235    43    60    23    16    53    48
# ISFJ    25    65   102   190   122   235    37    80    26    13    42    52
# INTJ    10    18    29    63    26    87    13    13     8     7    11    12
# ...

# %% [markdown]
# * 메세지 로그

# %%
msg_df
# Out:
#          mem_no mem_sex mem_mbti_code  ptr_mem_no ptr_mem_sex ptr_mbti_code  \
# 0       1648522       f          ESFP     1583736           m          ISFJ
# 1       1648522       f          ESFP     1583736           m          ISFJ
# 2       1648522       f          ESFP     1583736           m          ISFJ
# 3       1648522       f          ESFP     1583736           m          ISFJ
# 4       1648522       f          ESFP     1583736           m          ISFJ
# ...         ...     ...           ...         ...         ...           ...
# 455715  1671234       m          INFP     1426225           f          INFP
# 455716   155715       m          ISFP     1513715           f          INFJ
# 455717  1671422       f          ENFP     1671468           m          INFJ
# 455718  1360816       f          INFP     1282906           m          ESTP
# 455719  1360816       f          INFP      438558           m          ENFJ
#
#         msg_type             ins_date
# ...

# %%
msg_df1 = dict(msg_df[msg_df['mem_mbti_code']=="ISTJ"].ptr_mbti_code.value_counts())
msg_df2 = dict(msg_df[msg_df['mem_mbti_code']=="ISTP"].ptr_mbti_code.value_counts())
msg_df3 = dict(msg_df[msg_df['mem_mbti_code']=="ISFJ"].ptr_mbti_code.value_counts())
msg_df4 = dict(msg_df[msg_df['mem_mbti_code']=="ISFP"].ptr_mbti_code.value_counts())
msg_df5 = dict(msg_df[msg_df['mem_mbti_code']=="INFJ"].ptr_mbti_code.value_counts())
msg_df6 = dict(msg_df[msg_df['mem_mbti_code']=="INFP"].ptr_mbti_code.value_counts())
msg_df7 = dict(msg_df[msg_df['mem_mbti_code']=="INTJ"].ptr_mbti_code.value_counts())
msg_df8 = dict(msg_df[msg_df['mem_mbti_code']=="INTP"].ptr_mbti_code.value_counts())

msg_df9 = dict(msg_df[msg_df['mem_mbti_code']=="ESTJ"].ptr_mbti_code.value_counts())
msg_df10 = dict(msg_df[msg_df['mem_mbti_code']=="ESTP"].ptr_mbti_code.value_counts())
msg_df11 = dict(msg_df[msg_df['mem_mbti_code']=="ESFJ"].ptr_mbti_code.value_counts())
msg_df12 = dict(msg_df[msg_df['mem_mbti_code']=="ESFP"].ptr_mbti_code.value_counts())
msg_df13 = dict(msg_df[msg_df['mem_mbti_code']=="ENFJ"].ptr_mbti_code.value_counts())
msg_df14 = dict(msg_df[msg_df['mem_mbti_code']=="ENFP"].ptr_mbti_code.value_counts())
msg_df15 = dict(msg_df[msg_df['mem_mbti_code']=="ENTJ"].ptr_mbti_code.value_counts())
msg_df16 = dict(msg_df[msg_df['mem_mbti_code']=="ENTP"].ptr_mbti_code.value_counts())

msg_df1
# Out:
# {'INFP': 3203,
#  'ISFP': 1693,
#  'ENFP': 1658,
#  'INFJ': 1127,
#  'ISFJ': 1005,
#  'ENFJ': 935,
#  'ESFP': 848,
#  'ESFJ': 837,
#  'ISTJ': 542,
#  'INTJ': 524,
#  'INTP': 477,
#  'ENTP': 462,
#  'ESTJ': 336,
#  'ISTP': 293,
#  'ESTP': 230,
#  'ENTJ': 179}

# %%
msg_df1 = pd.DataFrame(msg_df1,index =['ISTJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
msg_df2 = pd.DataFrame(msg_df2,index =['ISTP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
msg_df3 = pd.DataFrame(msg_df3,index =['ISFJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
msg_df4 = pd.DataFrame(msg_df4,index =['ISFP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
msg_df5 = pd.DataFrame(msg_df5,index =['INFJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
msg_df6 = pd.DataFrame(msg_df6,index =['INFP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
msg_df7 = pd.DataFrame(msg_df7,index =['INTJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
msg_df8 = pd.DataFrame(msg_df8,index =['INTP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])


msg_df9 = pd.DataFrame(msg_df9,index =['ESTJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
msg_df10 = pd.DataFrame(msg_df10,index =['ESTP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
msg_df11 = pd.DataFrame(msg_df11,index =['ESFJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
msg_df12 = pd.DataFrame(msg_df12,index =['ESFP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
msg_df13 = pd.DataFrame(msg_df13,index =['ENFJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
msg_df14 = pd.DataFrame(msg_df14,index =['ENFP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
msg_df15 = pd.DataFrame(msg_df15,index =['ENTJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
msg_df16 = pd.DataFrame(msg_df16,index =['ENTP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])

# %%
new_msg = pd.concat([msg_df1,msg_df2,msg_df3,msg_df4,msg_df5,msg_df6,msg_df7,msg_df8,msg_df9,msg_df10,msg_df11,msg_df12,msg_df13,msg_df14,msg_df15,msg_df16])
new_msg = new_msg.fillna(0)
new_msg = new_msg.transpose()
new_msg
# Out:
#       ISTJ  ISTP  ISFJ   ISFP  INFJ   INFP  INTJ  INTP  ESTJ  ESTP  ESFJ  \
# ISFP  1693  2420  4448   6376  7576  13617  1783  3353  1416   853  2855
# INFP  3203  3293  6917  10276  7434  16981  2747  4530  1826  1294  4010
# ENTP   462   814   874   1922  1068   2393   439   498   382   184   639
# ESTJ   336   369   948   1111  1106   1959   210   483   110   218   349
# ESFP   848  1071  2267   2310  3506   4413   916  1275   432   259  1268
# ESFJ   837   535  1687   2716  2138   4606   704  1408   380   261   969
# ENTJ   179   454  1139    996   935   2038   455   433   178   118   413
# INFJ  1127  1286  2875   5609  3483   6622  1009  1993   924   593  1414
# ENFP  1658  1445  3329   4596  3790   8669  2046  1974  1146   347  1553
# ISFJ  1005  1491  3758   3896  3542   7812  1020  1866   877   820  1698
# INTJ   524   496  1071   1577  1185   3052   527   451   240   104   461
# INTP   477  1069  1631   2773  2355   4979   393  1150   426   558  1252
# ...

# %% [markdown]
# * 프로필 열람 로그

# %%
pf_view_df
# Out:
#           mem_no mem_sex mem_mbti_code  ptr_mem_no ptr_mem_sex ptr_mbti_code  \
# 0        1604615       m          INFP     1646817           f          ENFJ
# 1        1328139       m          ISTP     1646817           f          ENFJ
# 2        1314528       m          ENFP     1646817           f          ENFJ
# 3         992443       m          ISFJ     1646817           f          ENFJ
# 4         992443       m          ISFJ     1646817           f          ENFJ
# ...          ...     ...           ...         ...         ...           ...
# 1859507  1686164       f          INFP     1076051           m          INFJ
# 1859508  1687693       f          ISFP     1285085           m          INFJ
# 1859509  1687693       f          ISFP     1285085           m          INFJ
# 1859510  1687693       f          ISFP      503528           m          ISFJ
# 1859511  1687693       f          ISFP      503528           m          ISFJ
#
#          open_type            open_date
# ...

# %%
pf_view_df1 = dict(pf_view_df[pf_view_df['mem_mbti_code']=="ISTJ"].ptr_mbti_code.value_counts())
pf_view_df2 = dict(pf_view_df[pf_view_df['mem_mbti_code']=="ISTP"].ptr_mbti_code.value_counts())
pf_view_df3 = dict(pf_view_df[pf_view_df['mem_mbti_code']=="ISFJ"].ptr_mbti_code.value_counts())
pf_view_df4 = dict(pf_view_df[pf_view_df['mem_mbti_code']=="ISFP"].ptr_mbti_code.value_counts())
pf_view_df5 = dict(pf_view_df[pf_view_df['mem_mbti_code']=="INFJ"].ptr_mbti_code.value_counts())
pf_view_df6 = dict(pf_view_df[pf_view_df['mem_mbti_code']=="INFP"].ptr_mbti_code.value_counts())
pf_view_df7 = dict(pf_view_df[pf_view_df['mem_mbti_code']=="INTJ"].ptr_mbti_code.value_counts())
pf_view_df8 = dict(pf_view_df[pf_view_df['mem_mbti_code']=="INTP"].ptr_mbti_code.value_counts())

pf_view_df9 = dict(pf_view_df[pf_view_df['mem_mbti_code']=="ESTJ"].ptr_mbti_code.value_counts())
pf_view_df10 = dict(pf_view_df[pf_view_df['mem_mbti_code']=="ESTP"].ptr_mbti_code.value_counts())
pf_view_df11 = dict(pf_view_df[pf_view_df['mem_mbti_code']=="ESFJ"].ptr_mbti_code.value_counts())
pf_view_df12 = dict(pf_view_df[pf_view_df['mem_mbti_code']=="ESFP"].ptr_mbti_code.value_counts())
pf_view_df13 = dict(pf_view_df[pf_view_df['mem_mbti_code']=="ENFJ"].ptr_mbti_code.value_counts())
pf_view_df14 = dict(pf_view_df[pf_view_df['mem_mbti_code']=="ENFP"].ptr_mbti_code.value_counts())
pf_view_df15 = dict(pf_view_df[pf_view_df['mem_mbti_code']=="ENTJ"].ptr_mbti_code.value_counts())
pf_view_df16 = dict(pf_view_df[pf_view_df['mem_mbti_code']=="ENTP"].ptr_mbti_code.value_counts())

pf_view_df1
# Out:
# {'INFP': 9020,
#  'ISFP': 7084,
#  'INFJ': 4128,
#  'ISFJ': 4074,
#  'ENFP': 4032,
#  'ENFJ': 3721,
#  'ESFP': 3170,
#  'INTP': 2477,
#  'ESFJ': 2438,
#  'ISTP': 2154,
#  'ISTJ': 1727,
#  'ENTP': 1244,
#  'INTJ': 1243,
#  'ENTJ': 1242,
#  'ESTP': 1091,
#  'ESTJ': 963}

# %%
pf_view_df1 = pd.DataFrame(pf_view_df1,index =['ISTJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
pf_view_df2 = pd.DataFrame(pf_view_df2,index =['ISTP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
pf_view_df3 = pd.DataFrame(pf_view_df3,index =['ISFJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
pf_view_df4 = pd.DataFrame(pf_view_df4,index =['ISFP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
pf_view_df5 = pd.DataFrame(pf_view_df5,index =['INFJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
pf_view_df6 = pd.DataFrame(pf_view_df6,index =['INFP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
pf_view_df7 = pd.DataFrame(pf_view_df7,index =['INTJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
pf_view_df8 = pd.DataFrame(pf_view_df8,index =['INTP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])


pf_view_df9 = pd.DataFrame(pf_view_df9,index =['ESTJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
pf_view_df10 = pd.DataFrame(pf_view_df10,index =['ESTP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
pf_view_df11 = pd.DataFrame(pf_view_df11,index =['ESFJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
pf_view_df12 = pd.DataFrame(pf_view_df12,index =['ESFP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
pf_view_df13 = pd.DataFrame(pf_view_df13,index =['ENFJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
pf_view_df14 = pd.DataFrame(pf_view_df14,index =['ENFP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
pf_view_df15 = pd.DataFrame(pf_view_df15,index =['ENTJ'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])
pf_view_df16 = pd.DataFrame(pf_view_df16,index =['ENTP'],columns=['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ',
       'ENFP', 'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'])

# %%
new_pf = pd.concat([pf_view_df1,pf_view_df2,pf_view_df3,pf_view_df4,pf_view_df5,pf_view_df6,pf_view_df7,pf_view_df8,pf_view_df9,pf_view_df10,pf_view_df11,pf_view_df12,pf_view_df13,pf_view_df14,pf_view_df15,pf_view_df16])
new_pf = new_pf.fillna(0)
new_pf = new_pf.transpose()
new_pf
# Out:
#       ISTJ   ISTP   ISFJ   ISFP   INFJ   INFP   INTJ   INTP  ESTJ  ESTP  \
# ISFP  7084  12919  19424  35301  27568  59663   7429  13951  4020  3652
# INFP  9020  17725  25286  48428  34235  81482  10148  19169  5468  5089
# ENTP  1244   2424   3621   6664   5160  11256   1508   2586   755   674
# ESTJ   963   1821   2878   5167   3766   7450   1043   1723   556   510
# ESFP  3170   5895   9729  15658  13346  26709   3291   6246  1753  1627
# ESFJ  2438   4375   7154  12884   9756  19303   2490   4386  1332  1332
# ENTJ  1242   2249   3620   6057   4906  10807   1294   2642   699   647
# INFJ  4128   7210  11419  20345  14662  31631   4035   7827  2448  2316
# ENFP  4032   7622  11083  20359  16650  34648   4352   8238  2180  2148
# ISFJ  4074   7471  11992  20196  15500  31951   4242   7153  2263  2298
# INTJ  1243   2199   3742   6516   4593  10793   1566   2504   754   723
# INTP  2477   4677   7155  13167  10120  22057   2751   5336  1453  1412
# ...

# %% [markdown]
# * 모든 로그 MBTI합
#     - column이 ISTJ일 때의 row값 확인

# %%
new_df = new_concn + new_msg + new_pf + new_want
new_df
# Out:
#        ISTJ   ISTP   ISFJ   ISFP   INFJ   INFP   INTJ   INTP  ESTJ  ESTP  \
# ISFP   8815  15428  24037  42039  35354  73730   9283  17404  5483  4539
# INFP  12259  21133  32381  59095  41921  99104  13002  23852  7374  6411
# ENTP   1715   3251   4515   8632   6262  13739   1961   3098  1140   862
# ESTJ   1308   2206   3846   6316   4910   9483   1263   2213   672   735
# ESFP   4044   7021  12074  18105  16958  31349   4238   7591  2203  1906
# ESFJ   3294   4943   8888  15721  11987  24060   3216   5835  1732  1614
# ENTJ   1429   2713   4789   7107   5886  12942   1762   3099   887   767
# INFJ   5282   8543  14349  26129  18256  38481   5071   9871  3399  2925
# ENFP   5707   9117  14494  25133  20587  43573   6442  10275  3357  2513
# ISFJ   5105   9033  15860  24297  19172  40016   5302   9105  3180  3132
# INTJ   1777   2714   4844   8164   5807  13937   2106   2969  1004   835
# INTP   2969   5778   8826  16025  12552  27210   3165   6530  1898  1978
# ...

# %%
new_df.index
# Out:
# Index(['ISFP', 'INFP', 'ENTP', 'ESTJ', 'ESFP', 'ESFJ', 'ENTJ', 'INFJ', 'ENFP',
#        'ISFJ', 'INTJ', 'INTP', 'ESTP', 'ENFJ', 'ISTP', 'ISTJ'],
#       dtype='object')

# %%
new_df.columns
# Out:
# Index(['ISTJ', 'ISTP', 'ISFJ', 'ISFP', 'INFJ', 'INFP', 'INTJ', 'INTP', 'ESTJ',
#        'ESTP', 'ESFJ', 'ESFP', 'ENFJ', 'ENFP', 'ENTJ', 'ENTP'],
#       dtype='object')

# %%
m_list = []
m_list2 = []
for i in range(len(mbti_list)):
    m_list.append(list(new_df[mbti_list[i]].sort_values(ascending=False).index))

for i in range(len(m_list)):
    m_list2.append(m_list[i][:4])
m_list2
# Out:
# [['INFP', 'ISFP', 'ENFP', 'INFJ'],
#  ['INFP', 'ISFP', 'ENFP', 'ISFJ'],
#  ['INFP', 'ISFP', 'ISFJ', 'ENFP'],
#  ['INFP', 'ISFP', 'INFJ', 'ENFP'],
#  ['INFP', 'ISFP', 'ENFP', 'ISFJ'],
#  ['INFP', 'ISFP', 'ENFP', 'ISFJ'],
#  ['INFP', 'ISFP', 'ENFP', 'ISFJ'],
#  ['INFP', 'ISFP', 'ENFP', 'INFJ'],
#  ['INFP', 'ISFP', 'INFJ', 'ENFP'],
#  ['INFP', 'ISFP', 'ISFJ', 'INFJ'],
#  ['INFP', 'ISFP', 'ISFJ', 'INFJ'],
#  ['INFP', 'ISFP', 'INFJ', 'ISFJ'],
#  ['INFP', 'ISFP', 'ENFP', 'ISFJ'],
#  ['INFP', 'ISFP', 'INFJ', 'ENFP'],
#  ['INFP', 'ISFP', 'ENFP', 'ISFJ'],
#  ['INFP', 'ISFP', 'ENFJ', 'ENFP']]

# %% [markdown]
# * 1순위 MBTI 분류

# %%
new_df.idxmax()
df_1 = pd.DataFrame(index=new_df.columns,columns=['1st'],data=new_df.idxmax())
df_2 = pd.DataFrame(index=new_df.columns,columns=['2nd'],data='ISFP')
# df_3 = pd.DataFrame(index=new_df.columns,columns=['3st'],data='ISFP')
pd.concat([df_1,df_2],axis=1)
# Out:
#        1st   2nd
# ISTJ  INFP  ISFP
# ISTP  INFP  ISFP
# ISFJ  INFP  ISFP
# ISFP  INFP  ISFP
# INFJ  INFP  ISFP
# INFP  INFP  ISFP
# INTJ  INFP  ISFP
# INTP  INFP  ISFP
# ESTJ  INFP  ISFP
# ESTP  INFP  ISFP
# ESFJ  INFP  ISFP
# ESFP  INFP  ISFP
# ENFJ  INFP  ISFP
# ENFP  INFP  ISFP
# ENTJ  INFP  ISFP
# ENTP  INFP  ISFP

# %% [markdown]
# * 결혼 성공 사례 로그

# %%
# married_df.columns

# %%
# married_df

# %%
# # df_edit = df.drop(['Unnamed: 0'],axis=1)

# married_df_edit = pd.merge(df_edit, married_df, on = 'mem_no', how = 'inner')
# married_df_edit

# %%
# married_df_edit = pd.merge(married_df_edit, want_df, on = 'ptr_mem_no', how = 'inner')
# married_df_edit
